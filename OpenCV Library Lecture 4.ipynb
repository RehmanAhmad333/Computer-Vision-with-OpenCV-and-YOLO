# %% [markdown]
# # 🧠 Computer Vision Basics – Lecture 4
# #### Topic: Live Detection (Webcam)
# **Instructor:** Azeem Aslam
# <br>
# **Institute:** UVAS / NAVTTC

# %% [markdown]
# # 🎯 What you will learn today
# By the end, you can:
#
# - Run live face detection using your webcam
# - Understand real-time video = many images per second
# - See a demo of YOLO (detects many objects: person, car, phone, etc.)
# - Understand the simple difference:
#     - Image Processing (we tell computer rules)
#     - AI / YOLO (computer learns from many examples)
#
# > This lecture is a WOW lecture 😄
# Students usually love this one.
#
# # Quick Reminder
# **An image**
# = one photo
#
# **A video**
# = many photos quickly
# (Example: 30 photos every second)
#
# So in real-time:
#
# 1. camera gives a frame (photo)
# 2. computer detects face/object
# 3. computer shows result
# 4. repeat again and again

# %%
pip uninstall opencv-python opencv-python-headless -y

# %%
pip install opencv-python

# %%
import cv2
print(cv2.__file__)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\cv2\__init__.py

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Part A: Live Face Detection (Webcam)
# ### ⚠️ Important Notes
# - This works best on a laptop/PC with webcam
# - In some environments (like some cloud notebooks), webcam may not open.
# - Press Q to quit the webcam window.
#
# ---
#
# # Step A1: Load the ready-made face detector

# %%
face_cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(face_cascade_path)

if face_cascade.empty():
    print("Face detector Not loaded.")
else:
    print("Face detector loaded:", face_cascade_path)
# Out:
# Face detector loaded: C:\Users\User\anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml

# %% [markdown]
# # Step A2: Start webcam and detect faces live
# **What students should understand:**
#
# - Camera gives a frame
# - Convert frame to grayscale
# - Detect faces
# - Draw box
# - Show frame
# - Press Q to stop.

# %%
# Live Face Detection

cap = cv2.VideoCapture(0)  # 0 mean default camera

if not cap.isOpened():
    print("Webcam not opened . Try changing 0 to 1 or check camera promissions.")
else:
    print("Webcam started . Pree Q to quit.")

    while True:
        ret , frame = cap.read()
        if not ret:
            print("Could not read frame.")
            break

        gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(
            gray, 
            scaleFactor=1.1,
            minNeighbors = 7,
            minSize=(40,40)
        )

        for (x , y , w , h) in faces:
            cv2.rectangle(frame , (x , y)   , (w+x  , y+h)  ,(255 , 0 , 255) , 2)

        cv2.putText(frame, f"Faces: {len(faces)}", (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # frame_rgb = cv2.cvtColor(frame , cv2.COLOR_BGR2RGB)

        cv2.imshow("Live Face Detection (Press Q to quit)", frame)
        # plt.imshow(frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Webcam started . Pree Q to quit.
